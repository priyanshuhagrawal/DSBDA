# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Mule\Desktop\Data set\forestfires.csv')
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
#data cleaning
df.rename(columns={'rain':'rain_'}, inplace=True)
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain_   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7    0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9    0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3    0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0    0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8    0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...    ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7    0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8    0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7    0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0    0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5    0.0   0.00
#
# [517 rows x 13 columns]

# %%
#data transformation
df["new_Column"] = pd.NaT
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain_   area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7    0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9    0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3    0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0    0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8    0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...    ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7    0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8    0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7    0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0    0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5    0.0   0.00
#
#     new_Column
# 0          NaT
# ...

# %%
#error correcting
df["new_Column"] = pd.NaT
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain_   area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7    0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9    0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3    0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0    0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8    0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...    ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7    0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8    0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7    0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0    0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5    0.0   0.00
#
#     new_Column
# 0          NaT
# ...

# %%
df.isnull().sum()
# Out:
# X               0
# Y               0
# month           0
# day             0
# FFMC            0
# DMC             0
# DC              0
# ISI             0
# temp            0
# RH              0
# wind            0
# rain_           0
# area            0
# new_Column    517
# dtype: int64

# %%
df['new_Column'] = df['new_Column'].replace(np.nan, 0)
df.isna().sum()
# Out:
# X             0
# Y             0
# month         0
# day           0
# FFMC          0
# DMC           0
# DC            0
# ISI           0
# temp          0
# RH            0
# wind          0
# rain_         0
# area          0
# new_Column    0
# dtype: int64

# %%
#model building
from sklearn.linear_model import LinearRegression

# %%
A = df['area']
B = df['wind']

# %%
lm = LinearRegression(fit_intercept=False)

# %%
lm.fit(df[['area']],df.wind)
# Out:
# LinearRegression(fit_intercept=False)

# %%
df.plot(kind= 'line', x='area' , y='wind')
# Out:
# <AxesSubplot:xlabel='area'>

# %%
sns.set_theme(style='whitegrid')
df.shape
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1

scale=1.5
lower_lim=Q1-scale*IQR
upper_lim=Q3+scale*IQR

lower_outliners = (df[df.columns[2:13]] < lower_lim)
upper_outliners = (df[df.columns[2:13]] > upper_lim)
# Out:
# C:\Users\Mule\AppData\Local\Temp/ipykernel_36904/4179388654.py:11: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   lower_outliners = (df[df.columns[2:13]] < lower_lim)
# C:\Users\Mule\AppData\Local\Temp/ipykernel_36904/4179388654.py:12: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   upper_outliners = (df[df.columns[2:13]] > upper_lim)

# %%
df[df.columns[2:13]][(lower_outliners | upper_outliners)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   month   0 non-null      object
#  1   day     0 non-null      object
#  2   FFMC    53 non-null     float64
#  3   DMC     17 non-null     float64
#  4   DC      8 non-null      float64
#  5   ISI     23 non-null     float64
#  6   temp    2 non-null      float64
#  7   RH      12 non-null     float64
#  8   wind    13 non-null     float64
#  9   rain_   8 non-null      float64
#  10  area    63 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 44.6+ KB
